# %%
# !pip install pymongo pandas certifi

# %%
import pandas as pd
import pymongo
import certifi

# %%
df = pd.read_csv("Crop_recommendation.csv")

print(df.shape)
df.head()
# Out:
# (2200, 8)
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
data = df.to_dict(orient="records")

print(f"Total records: {len(data)}")
# Out:
# Total records: 2200

# %%
DB_NAME = "Krishisevak1"

COLLECTION_NAME = "crop_recommendation_data"

CONNECTION_URL = "mongodb+srv://dhruvkul2004_db_user:y5y2bpicKSzgISeQ@cluster0.jmkhkmt.mongodb.net/?appName=Cluster0"

# %%
client = pymongo.MongoClient(
    CONNECTION_URL,
    tlsCAFile=certifi.where()
)

db = client[DB_NAME]

collection = db[COLLECTION_NAME]

print("Connected Successfully")
# Out:
# Connected Successfully

# %%
result = collection.insert_many(data)

print("Inserted Records:", len(result.inserted_ids))
# Out:
# Inserted Records: 2200

# %%
uploaded_df = pd.DataFrame(
    list(collection.find())
)

uploaded_df.head()
# Out:
#                         _id   N   P   K  temperature   humidity        ph  \
# 0  6a3b48e191589d5298c5a247  90  42  43    20.879744  82.002744  6.502985
# 1  6a3b48e191589d5298c5a248  85  58  41    21.770462  80.319644  7.038096
# 2  6a3b48e191589d5298c5a249  60  55  44    23.004459  82.320763  7.840207
# 3  6a3b48e191589d5298c5a24a  74  35  40    26.491096  80.158363  6.980401
# 4  6a3b48e191589d5298c5a24b  78  42  42    20.130175  81.604873  7.628473
#
#      rainfall label
# 0  202.935536  rice
# 1  226.655537  rice
# 2  263.964248  rice
# 3  242.864034  rice
# 4  262.717340  rice

# %%
collection.count_documents({})
# Out:
# 2200
